# %% [markdown]
# # Exam Workspace
#
# You will need the **permuations** formula which is based upon the combinations formula **choose()**.

# %%
perm <- function(n, k) {
    return(choose(n,k) * factorial(k))}

# %% [markdown]
# You will also need the following data frames, so I imported them for you.

# %%
pers <- read.csv('http://faculty.ung.edu/rsinn/data/personality.csv')
births <-  read.csv('http://faculty.ung.edu/rsinn/data/baby.csv')

# %% [markdown]
# ## Start your work in the spaces below
