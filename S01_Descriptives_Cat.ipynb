# %% [markdown]
# # S1: Descriptives and the cat() Function
#
# Let's review reading in data and sub-setting dataframe while summarizing numeric cata with descriptives. We will also utilize the **cat()** function and learn some of the basic about our standard graphics in R.

# %%
pers <- read.csv('https://faculty.ung.edu/rsinn/data/personality.csv')
air <- read.csv('https://faculty.ung.edu/rsinn/data/airports.csv')
baby <- read.csv('https://faculty.ung.edu/rsinn/data/baby.csv')

# %% [markdown]
# ## Sub-setting
#
# To create the numeric vectors we need so we can calculate some statistics, please complete the following tasks below:
#
# - **narc** : create a numeric vector named **narc** by extracting the column entitled "Narc" from the **pers** dataframe.
# - **ohco** : create a numeric vector named **ohco** by extracting the airport elevation data from the **air** dataframe for the states of Ohio and Colorado. All airport elevation data for both states should be included in a single numeric vector.
# - **momage** : create numeric vector named **momage** by extracting the "Maternal Age" column from the **baby** dataframe.

# %% [markdown]
# ## Descriptive Statistics
#
# Complete the following tasks to calculate the most common descriptive statistics:
#
# - Find the **average** of the **momage** vector.
# - Find the **standard deviation** of the **ohco** vector.
# - Find the **five number summary** of the **narc** vector.
# - Find the **sample size** of the **ohco** vector.

# %% [markdown]
# ## The cat() Function
#
# Complete the following tasks to learn to leverage the **cat()** function in R which allows us to format text and include the output of variables in one command.
#
# - Find and format the **standard descriptives** (mean, standard deviation, and sample size) for the **momage** vector.
# - Find and format the **standard deviation** and the **five number summary** for the **ohco** vector.
# - Find and format the **standard descriptives** and the **five number summary** for the **narc** vector.
