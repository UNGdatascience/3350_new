# %% [markdown]
# ## Exam Review Guide
#
# We will only need the formulas for the functions that calculate combinations and permutations plus a few data frames loaded below that formula.

# %%
perm <- function(n, k) {
    return(choose(n,k) * factorial(k))}

# %%
pers <- read.csv('http://faculty.ung.edu/rsinn/data/personality.csv')
births <-  read.csv('http://faculty.ung.edu/rsinn/data/baby.csv')
united <- read.csv('http://faculty.ung.edu/rsinn/data/united.csv')
airports <- read.csv('http://faculty.ung.edu/rsinn/data/airports.csv')

# %% [markdown]
# ## Probability Topics
#
# ### Permutations
# 1. In a state where license plates have two letters followed by four digits, how many license plates are possible if:
#     - No letter or number can repeat.
#     - Only letters can repeat but not numbers.
#     - Both letters and numbers can repeat.
#
# </br>
# 2. In how many ways can a violin section elect a 1st chair and 2nd chair if there are eleven violinists in the orchestra?

# %% [markdown]
# ### Combinations and Partitions
#
# 3. How many flushes are possible when drawing a 5-card poker hand from a standard deck of $52$ randomly shuffled playing cards?
#
# 4. How many full houses are possible when drawing a 5-card poker hand from a standard deck of $52$ randomly shuffled playing cards?

# %% [markdown]
# ### Conditional Probability
#
# Recall the **conditional probability** formula:
# $$P(A \mid B) = \frac{P(A \cap B)}{P(B)}$$
#
# 5. In a neighborhood of 125 houses, 50 houses have cats only and 40 houses have both a dog a cat. If 15 houses have no pets, how many houses have dogs only?
#
# 6. An urn contains 6 crimson and 4 navy marbles. A marble is drawn at random and returned to the urn along with 2 additional marblesof the same color. A 2nd marble is then drawn. What is the probability that:
#     - The 2nd marble is crimson given the 1st marble was crimson?
#     - The 1st marble was crimson given the 2nd marble is crimson?

# %% [markdown]
# ## Independence
#
# 7. Consider a standard 52-card deck. Define 3 events. Event $H$: The card is a Heart. Event $F$: The card is a Face card (Jack, Queen, or King). Event $R$: The card is a Red card (Heart or Diamond). \textbf{Task: }Determine which pairs of events are independent.
#
# 8. An engineering system consists of three components: $A$, $B$, and $C$. The system functions if component $A$ works and at least one of components $B$ or $C$ works. Assume the components fail independently of one another with:
#     - $P(\text{Fail}_A) = 0.05$
#     - $P(\text{Fail}_B) = 0.10$
#     - $P(\text{Fail}_C) = 0.20$
# </br>
# <b>Task: </b>Calculate the probability that the entire system functions.

# %% [markdown]
# ### Expected Value and Variance
# 9. A technology company is bidding on a contract. There is a 30\% chance they will win a "Premium" contract worth $\$100,000$, a $50\%$ chance they will win a "Standard" contract worth $\$40,000$, and a $20\%$ chance they will lose the bid and receive nothing. It costs the company $\$15,000$ in administrative fees just to submit the bid. Calculate $E(X), V(X), \text{and} \sigma_X$.
#
# 10. A player pays $\$5$ to play a game where they roll two fair six-sided dice. If the sum is $12$, they win $\$30$. If the sum is 7, they win $\$10$. For any other sum, they win nothing.
#     - Find the expected value of the player's net profit.
#     - Calculate the variance.
#     - Calculate the standard deviation $\sigma$.

# %% [markdown]
# ### Discrete Probability Functions
# 11. A student consistently parks illegally in a **Faculty Only** lot. The probability of being caught and ticketed on any given day is 0.15, independent of other days. Let $X$ be the simple random variable counting the number of days the student parks there until he or she receives their first ticket. What is the probability the student parks there for 10 days before receiving a ticket on the 11th day?
#
# 12. If the student above will park in the **Faculty Only** lot until he or she receives four tickets, what the probability the student will park there for 20 day before the 4th ticket is received.

# %% [markdown]
# ## Statistics
#
# 13. A university claims that faculty members spend an average of 15 hours per week on research-related activities. A group of 30 faculty members was surveyed to see if their time commitment differs significantly from this claim.
# $$\begin{array}{cccccccccc}12.5&14.0&15.5&13.0&16.0&14.5&15.0&13.5&14.0&12.0 \\ 16.5&15.0&14.0&13.0&15.5&14.5&15.0&13.5&14.5&12.5 \\ 16.0&14.0&15.0&13.5&14.0&13.0&15.5&14.5&15.0&13.5\\ \end{array}$$

# %% [markdown]
# 14.   **Eye color experiment.** Does the distribution of eye colors within our class at UNG match the nationwide distribution?
# $$\begin{array}{ccccc}\textbf{Blue}&\textbf{Hazel}&\textbf{Green}&\textbf{Light Brown}&\textbf{Dark Brown} \\ 32\%&15\%&12\%&16\%&2\%5\end{array}$$
#
# From a 2021 stats class, we can use this sample data: 5 Blue, 1 Hazel, 3 Green, 1 Light Brown and 7 Dark Brown.

# %% [markdown]
# 15. A study compared the price of a specific high-end leather jacket at independent boutique shops versus major department stores on the East Coast.
# $$\begin{array}{ccccccccccccccccc}  \textbf{Boutiques} & 450& 475& 460& 490 &455\\&480 &470 &465 &440 &485 \\&495 &450 &460 &470 &480\\ \\\textbf{Department Stores} & 420 & 430 &425 &440 &415\\  &435 &425 &420 &410& 445\\& 450& 420, &430& 425 &435  \end{array}$$

# %% [markdown]
# 16. In medical statistics, researchers often test if the location of a vaccine injection (Thigh vs. Arm) impacts the severity of the local reaction.
# $$\begin{array}{lcc}\textbf{Reaction Severity}&\textbf{Thigh Injection}&\textbf{Arm Injection} \\ \textbf{No Reaction}&4758&8840 \\ \textbf{Swelling} & 30 & 76 \\ \textbf{Pain} & 15 & 42\end{array}$$
#
# Test the hypothesis that reaction severity depends upon injection location at the $\alpha = 0.025$ level.
