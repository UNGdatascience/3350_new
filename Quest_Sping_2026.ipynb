# %% [markdown]
# # Quest: Statistics (MATH 3350)
#
# We have several data sets which can be found here: [Robb's Faculty Webpage: Data Sets](https://faculty.ung.edu/rsinn/data/). We will load the following data frames.
#
# - **pers** -- Personality data set
# - **births** -- Babies with smoking vs. non-smoking moms data set
# - **united** -- Airline data set with specific United flights and delays (in minutes)
# - **airports** -- World airports data set

# %%
pers <- read.csv('http://faculty.ung.edu/rsinn/data/personality.csv')
births <-  read.csv('http://faculty.ung.edu/rsinn/data/baby.csv')
united <- read.csv('http://faculty.ung.edu/rsinn/data/united.csv')
airports <- read.csv('http://faculty.ung.edu/rsinn/data/airports.csv')

atl <- subset(united, Destination == 'ATL')$Delay
dfw <- subset(united, Destination == 'DFW')$Delay

smoke <- subset(births, Maternal.Smoker == 'True')$Birth.Weight
non <- subset(births, Maternal.Smoker == 'False')$Birth.Weight

older_fem <-subset(pers, Sex == 'F' & Age >= 20)$Perf

opt <- pers$Opt
thrill <- pers$Thrill

# %% [markdown]
# # Task 1
#
# Conduct an **exploratory data analysis** on the numeric vector **atl** which represent the delays (in minutes) of flights arriving at the Atlanta airport. Be sure to complete all needed steps.

# %% [markdown]
# ## Task 2
#
# Conduct an independent samples $t$-test at the $\alpha = 0.05$ level to determine whether babies born to mothers who smoke during pregnancy weigh a different amount on average comparred to babies born to non-smoking moms. The two samples have been subsetted above: they are the numeric vectors **smoke** and **non**. Be sure to complete all needed steps including (but not limited to) setting up the hypotheses, doing the data checks and reporting out.

# %% [markdown]
# ## Task 3
#
# Determine at the $\alpha = 0.05$ level whether older females (age 20 years old or more) have Perfectionism levels higher than 106.The sample was  subsetted above: **older_fem**. Be sure to complete all needed steps including (but not limited to) setting up the hypotheses, doing the data checks and reporting out.

# %% [markdown]
# ## Task 4
#
# Determine at the $\alpha = 0.05$ level if a significant correlation exists between **Optimism** and **Thrill-seeking**. In the data frame **pers**, the column titles are **Opt** and **Thrill**. Be sure to complete all needed steps including (but not limited to) setting up the hypotheses, doing the data checks and reporting out.

# %% [markdown]
# ## Task 5
#
# Determine at the $\alpha = 0.025$ level whether differences exist in **Narcissism** based upon **Primary Humor Style**. The coloumn titles in the **pers** data frame are **Narc** and **PHS**. Be sure to complete all needed steps including (but not limited to) setting up the hypotheses, doing the data checks and reporting out. <b><span style='color:red'>If appropriate, conduct a *post hoc* analysis.</style></b>
